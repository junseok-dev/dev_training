# %% [markdown]
# `07_oop/homework_food_251106.ipynb`에서 작성하세요. # 205
#
# 다음 음식 주문 시스템 요구사항에 따라 필요 클래스를 설계하세요.
# - 다양한 음식점이 존재합니다.
# - 음식점은 한식/일식/중식음식점으로 크게 분류할 수 있습니다.
# - 각 음식점은 이름, 주소, 전화번호, 다수개의 메뉴를 가지고 있습니다.
# - 음식점의 메뉴는 식사류, 안주류, 음료류로 크게 분류할 수 있습니다.
# - 주문 내역을 관리할 수 있어야 합니다.
# - 주문에는 하나의 음식점, 여러개의 메뉴/수량을 기록하고 총금액정보를 가지고 있습니다.
# - 클래스를 설계하고, 직접 객체화하여 아래와 같이 출력되어야 합니다.
#
# ```
# ## 음식점 목록
# [한식당 - 장꼬방김치찌게]
# <주소: xxx>
# <전화번호: xxx>
#
# 김치찌개 - 8000원
# 비빔밥 - 7500원
# 된장찌개 - 7000원
# ---
#
#
# [일식당 - 까모메식당]
# <주소: xxx>
# <전화번호: xxx>
#
# 초밥세트 - 12000원
# 우동 - 9000원
# 돈카츠 - 10000원
# ---
#
# ## 주문내역
# [한식당 - 장꼬방김치찌게]
#
# 김치찌개 8000원 * 2개 16000원
# 비빔밥 - 7500원 * 1개 7500원
#
# 총결제금액: 23500원
# ```
#
# 다음은 예시 출력코드 입니다.
# ```python
# # 🍚 한식당 객체 생성
# k_restaurant = KoreanRestaurant("장꼬방김치찌개", "서울시 강남구 123", "02-123-4567")
# k_restaurant.add_menu(MenuItem("김치찌개", 8000, "식사"))
# k_restaurant.add_menu(MenuItem("비빔밥", 7500, "식사"))
# k_restaurant.add_menu(MenuItem("된장찌개", 7000, "식사"))
#
# # 🍣 일식당 객체 생성
# j_restaurant = JapaneseRestaurant("까모메식당", "서울시 용산구 456", "02-987-6543")
# j_restaurant.add_menu(MenuItem("초밥세트", 12000, "식사"))
# j_restaurant.add_menu(MenuItem("우동", 9000, "식사"))
# j_restaurant.add_menu(MenuItem("돈카츠", 10000, "식사"))
#
# # ✅ 출력: 음식점 목록
# print("## 음식점 목록")
# k_restaurant.display_info()
# k_restaurant.display_menu()
#
# j_restaurant.display_info()
# j_restaurant.display_menu()
#
# # ✅ 주문 생성 및 출력
# print("## 주문내역")
# order = Order(k_restaurant)
# order.add_item(k_restaurant.menu_items[0], 2)  # 김치찌개 * 2
# order.add_item(k_restaurant.menu_items[1], 1)  # 비빔밥 * 1
# order.display_order()
# ```
