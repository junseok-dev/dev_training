# %% [markdown]
# `_02_datatype/homework_251031.ipynb`에서 작성하세요. # 91
#
#
# #### 01.
# 어떤 실수가 주어졌을 때, 이 수를
# - 첫째 자리에서 반올림한 정수
# - 올림한 정수
# - 버림한 정수
# 를 출력하는 프로그램을 작성하시오.
# ```python
# # 예시 입력: 3.14
# # 예시 출력: 3 (반올림), 4 (올림), 3 (버림)
# ```
#
# ---
#
# #### 02.
# 사용자로부터 두 개의 숫자를 입력받아, 두 숫자가 같은지 비교하고 결과를 출력하시오.
# ```python
# # 예시 입력: 5, 5
# # 예시 출력: True
# ```
#
# ---
#
# #### 03.
# 정수 x가 10 이상이고 100 이하인지 판단하여 `True` 또는 `False`를 출력하시오.
# 힌트: and 연산자 사용
#
# ---
#
# #### 04.
# 0 에서 1 사이의 실수 하나를 입력받아, 소수점 이하가 0.5 이상이면 True를, 그렇지 않으면 False를 출력하시오.
# 힌트: `round()`, 비교연산자 사용
#
# ---
#
# #### 05.
# 사용자로부터 실수 하나를 입력받아 다음 조건을 모두 만족하는지 확인하라:
# - 소수점 첫째자리에서 올림한 값이 10보다 작다.
# - 소수점 이하를 버린 값이 5 이상이다.
# ```python
# # 위 두 조건을 and 연산자로 판단
# ```
#
# ---
#
# #### 06.
# 숫자 a와 b를 입력받아 다음 조건 중 하나라도 만족하면 `True`, 아니면 `False`를 출력하시오:
# - a가 b보다 크다
# - a를 반올림한 값이 b의 버림값보다 크다
# 힌트: `or`, `round()`, `math.floor()`
#
# ---
#
# #### 07.
# 임의의 실수 `x`가 주어졌을 때,
# - x의 올림값이 짝수이고
# - x의 반올림값이 10보다 작을 경우
# `True`를 출력하시오. 아니면 `False`.
# 힌트: `math.ceil(x) % 2 == 0`, `round(x) < 10`
#
# ---
#
# #### 08.
# 실수 `x`가 주어졌을 때, `버림값`, `반올림값`, `올림값`을 각각 구한 후 이 중 가장 큰 값을 출력하시오.
#
# ---
#
# #### 09.
# 사용자로부터 실수 하나를 입력받고, 다음 조건 중 하나라도 만족하면 "조건 만족", 아니면 "조건 불만족"을 출력하시오:
# - 반올림한 값이 5의 배수이다.
# - 올림한 값이 짝수이다.
#
# ---
#
# #### 10.
# 실수 두 개 `a`, `b`를 입력받고 다음 조건을 만족하는지 판별하시오:
# - a를 반올림한 값이 b를 반올림한 값보다 작거나 같고
# - a를 올림한 값이 b를 버림한 값보다 크다
#
#
# #### 11.
# ```python
# numbers = [5, 2, 9, 1, 7]
#
# ```
#
# 이 리스트에 다음 작업을 순서대로 수행해보자.
#
# 1. 리스트에 숫자 `3`을 추가한다.
# 2. 리스트를 오름차순으로 정렬한다.
# 3. 가장 큰 값을 제거한다.
# 4. 마지막 두 값을 제외한 나머지만 출력한다.
#
# ```python
# # TODO: 위 내용을 코드로 작성해보자
# numbers = [5, 2, 9, 1, 7]
#
# # 1. 값 추가
# # 2. 정렬
# # 3. 최대값 제거
# # 4. 슬라이싱 후 출력
#
# ```
#
# ---
#
# #### 12.
#
# ```python
# info = ("Alice", 25, "Engineer")
#
# ```
#
# 이 튜플에서 이름과 나이를 꺼내어 다음 형식으로 출력해보자.
#
# ```
# 이름은 Alice이고, 나이는 25살이다.
#
# ```
#
# *힌트:* 튜플의 인덱싱을 사용하자.
#
# ---
#
# #### 13.
#
# 다음은 학생들의 수학 점수를 나타내는 딕셔너리이다.
#
# ```python
# scores = {"Tom": 87, "Jane": 92, "Mike": 78}
#
# ```
#
# 1. "Mike"의 점수를 82로 수정하고,
# 2. "Lucy"의 점수를 95로 추가한 후,
# 3. 모든 학생의 평균 점수를 출력해보자.
#
# *힌트:* `values()`와 `sum()` 사용 가능.

# %% [markdown]
# #### 01.
# 어떤 실수가 주어졌을 때, 이 수를
# - 첫째 자리에서 반올림한 정수
# - 올림한 정수
# - 버림한 정수
# 를 출력하는 프로그램을 작성하시오.
# ```python
# # 예시 입력: 3.14
# # 예시 출력: 3 (반올림), 4 (올림), 3 (버림)
# ```

# %%
import math

x = float(input("실수 입력: "))

print(round(x)) # 반올림
print(math.ceil(x)) # 올림
print(math.floor(x)) # 버림
# Out:
# 1
# 1
# 0

# %% [markdown]
# #### 02.
# 사용자로부터 두 개의 숫자를 입력받아, 두 숫자가 같은지 비교하고 결과를 출력하시오.
# ```python
# # 예시 입력: 5, 5
# # 예시 출력: True
# ```

# %%
a = int(input("첫 번째 숫자: "))
b = int(input("두 번째 숫자"))

print( a == b)
# Out:
# True

# %% [markdown]
# #### 03.
# 정수 x가 10 이상이고 100 이하인지 판단하여 `True` 또는 `False`를 출력하시오.
# 힌트: and 연산자 사용

# %%
x = int(input("정수 입력: "))
print(10 <= x and x <= 100)
# Out:
# True

# %% [markdown]
# #### 04.
# 0 에서 1 사이의 실수 하나를 입력받아, 소수점 이하가 0.5 이상이면 True를, 그렇지 않으면 False를 출력하시오.
# 힌트: `round()`, 비교연산자 사용

# %%
x = float(input("0~1 사이의 실수 입력:"))

print((round(x)) >= 0.5)
# Out:
# False

# %% [markdown]
# #### 05.
# 사용자로부터 실수 하나를 입력받아 다음 조건을 모두 만족하는지 확인하라:
# - 소수점 첫째자리에서 올림한 값이 10보다 작다.
# - 소수점 이하를 버린 값이 5 이상이다.
# ```python
# # 위 두 조건을 and 연산자로 판단
# ```

# %%
import math

x = float(input("실수 입력: "))

condition = (math.ceil(x) < 10) and (math.floor(x) >= 5)
print(condition)
# Out:
# False

# %% [markdown]
# #### 06.
# 숫자 a와 b를 입력받아 다음 조건 중 하나라도 만족하면 `True`, 아니면 `False`를 출력하시오:
# - a가 b보다 크다
# - a를 반올림한 값이 b의 버림값보다 크다
# 힌트: `or`, `round()`, `math.floor()`

# %%
import math

a = float(input("a 입력: "))
b = float(input("b 입력: "))

condition = (a > b) or (round(a) > math.floor(b))
print(condition)

# %% [markdown]
# #### 07.
# 임의의 실수 `x`가 주어졌을 때,
# - x의 올림값이 짝수이고
# - x의 반올림값이 10보다 작을 경우
# `True`를 출력하시오. 아니면 `False`.
# 힌트: `math.ceil(x) % 2 == 0`, `round(x) < 10`

# %%
import math

x = float(input("실수 입력: "))

condition = (math.ceil(x) % 2 == 0) and (round(x) < 10)
print(condition)

# %% [markdown]
# #### 08.
# 실수 `x`가 주어졌을 때, `버림값`, `반올림값`, `올림값`을 각각 구한 후 이 중 가장 큰 값을 출력하시오.

# %%
import math

x = float(input("실수 입력: "))

values = [math.floor(x), round(x), math.ceil(x)]
print(max(values))

# %% [markdown]
# #### 09.
# 사용자로부터 실수 하나를 입력받고, 다음 조건 중 하나라도 만족하면 "조건 만족", 아니면 "조건 불만족"을 출력하시오:
# - 반올림한 값이 5의 배수이다.
# - 올림한 값이 짝수이다.

# %%
import math

x = float(input("실수 입력: "))

if round(x) % 5 == 0 or math.ceil(x) % 2 == 0:
    print("조건 만족")
else:
    print("조건 불만족")

# %% [markdown]
# #### 10.
# 실수 두 개 `a`, `b`를 입력받고 다음 조건을 만족하는지 판별하시오:
# - a를 반올림한 값이 b를 반올림한 값보다 작거나 같고
# - a를 올림한 값이 b를 버림한 값보다 크다

# %%
import math

a = float(input("a 입력: "))
b = float(input("b 입력: "))

condition = (round(a) <= round(b)) and (math.ceil(a) > math.floor(b))
print(condition)

# %% [markdown]
# #### 11.
# ```python
# numbers = [5, 2, 9, 1, 7]
#
# ```
#
# 이 리스트에 다음 작업을 순서대로 수행해보자.
#
# 1. 리스트에 숫자 `3`을 추가한다.
# 2. 리스트를 오름차순으로 정렬한다.
# 3. 가장 큰 값을 제거한다.
# 4. 마지막 두 값을 제외한 나머지만 출력한다.
#
# ```python
# # TODO: 위 내용을 코드로 작성해보자
# numbers = [5, 2, 9, 1, 7]
#
# # 1. 값 추가
# # 2. 정렬
# # 3. 최대값 제거
# # 4. 슬라이싱 후 출력
#
# ```

# %%
numbers = [5, 2, 9, 1, 7]

# 1. 값 추가
numbers.append(3)

# 2. 정렬
numbers.sort()

# 3. 최대값 제거
numbers.remove(max(numbers))

# 4. 마지막 두 값 제외 후 출력
print(numbers[:-2])

# %% [markdown]
# #### 12.
#
# ```python
# info = ("Alice", 25, "Engineer")
#
# ```
#
# 이 튜플에서 이름과 나이를 꺼내어 다음 형식으로 출력해보자.
#
# ```
# 이름은 Alice이고, 나이는 25살이다.
#
# ```
#
# *힌트:* 튜플의 인덱싱을 사용하자.

# %%
info = ("Alice", 25, "Engineer")

print(f"이름은 {info[0]} 이고, 나이는 {info[1]}살이다. 나는 {info[2]}야~")

# %% [markdown]
# #### 13.
#
# 다음은 학생들의 수학 점수를 나타내는 딕셔너리이다.
#
# ```python
# scores = {"Tom": 87, "Jane": 92, "Mike": 78}
#
# ```
#
# 1. "Mike"의 점수를 82로 수정하고,
# 2. "Lucy"의 점수를 95로 추가한 후,
# 3. 모든 학생의 평균 점수를 출력해보자.
#
# *힌트:* `values()`와 `sum()` 사용 가능.

# %%
scores = {"Tom": 87, "Jane": 92, "Mike": 78}

# 1. 수정
scores["Mike"] = 82

# 2. 추가
scores["Lucy"] = 95

# 3. 평균
average = sum(scores.values()) / len(scores)
print("평균 점수:", round(average, 2))
