# %% [markdown]
# # **파이썬 1일차**

# %% [markdown]
# ## `문장 (statement)`: 실행 할 수 있는 코드의 최소 단위
#
# ## `표현식 (expression)`: 어떤 값을 만들어내는 코드

# %% [markdown]
# ## `리터럴 (literal)`: 숫자만 표시 (10)
#
# ## `식별자 (identifier)`: 기호를 빌려 값을 표현 (n=10)
#
# ## `연산자 (operator)`: + | - | * | / | % | ** | // | and | or | not
#
# ## `키워드 (keyword)`: False | True | None | and | else | pass | or | not | in | return | elif | class | def | while | with | break | continue

# %% [markdown]
# ## 이스케이프 문자 : "\"안녕하세요\"라고 말했습니다." -> "안녕하세요"라고 말했습니다.
# ## \n : 줄바꿈
# ## \t : 탭문자
# ## \\\\ : 역슬래시 자체(\\)
# ## 여러줄 문자열 : print("""여러줄
# ## 문자열
# ## 입니다.
# ## """)
# ## 여러줄 문자열 : print(\
# ## """여러줄
# ## 문자열
# ## 입니다.
# ## 역슬래시를 이와 같이 사용한다면 줄을 바꿔 출력하지 않겠다고 선언하는 것 입니다.\
# ## """)

# %%
print("\"안녕하세요\"라고 말했습니다.")
print()
print("\"안녕하세요\"라고 말했습니다. \n 이건 줄바꿈 입니다.")
print()
print("\"안녕하세요\"라고 말했습니다. \t 이건 탭문자 입니다.")
print()
print("\"안녕하세요\"라고 말했습니다. \\ 이건 역슬래시 자체 입니다.")
print()
print("""안녕하세요.
저는 박준석 입니다. 이번 파이썬 공부에서는 
여러줄 문자열에 대해서 배우게 되었는데요. 
굉장히 설레는 마음입니다.
""")
print()
print("""\
안녕하세요.
저는 박준석 입니다. 이번 파이썬 공부에서는 
여러줄 문자열에 대해서 배우게 되었는데요. 
굉장히 설레는 마음입니다.\
""")
print()
print\
(1,2,3)
# Out:
# "안녕하세요"라고 말했습니다.
#
# "안녕하세요"라고 말했습니다.
#  이건 줄바꿈 입니다.
#
# "안녕하세요"라고 말했습니다. 	 이건 탭문자 입니다.
#
# "안녕하세요"라고 말했습니다. \ 이건 역슬래시 자체 입니다.
#
# 안녕하세요.
# 저는 박준석 입니다. 이번 파이썬 공부에서는
# 여러줄 문자열에 대해서 배우게 되었는데요.
# 굉장히 설레는 마음입니다.
#
#
# 안녕하세요.
# 저는 박준석 입니다. 이번 파이썬 공부에서는
# 여러줄 문자열에 대해서 배우게 되었는데요.
# 굉장히 설레는 마음입니다.
#
# 1 2 3
